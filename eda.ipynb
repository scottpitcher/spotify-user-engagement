# %%
# eda.py
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
data = pd.read_csv('data/user_data.csv')

# Basic statistics
print(data.describe())

# Check for missing values
print(data.isnull().sum())
# Out:
#          play_count       user_age
# count  2.114420e+05  211442.000000
# mean   3.407793e+02      41.468970
# std    2.302771e+04      13.596083
# min    2.000000e+00      18.000000
# 25%    2.000000e+00      30.000000
# 50%    7.000000e+00      42.000000
# 75%    2.000000e+01      54.000000
# max    8.886110e+06      65.000000
# user_id         0
# song_id         0
# play_count      0
# last_played     0
# user_age        0
# user_country    0
# dtype: int64

# %%
# Distribution of user ages
plt.figure(figsize=(10, 6))
sns.histplot(data['user_age'], kde=True)
plt.title('Distribution of User Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.savefig("figures/age_dist.png")
plt.show()

# %%
# User engagement over time
plt.figure(figsize=(10, 6))
data['last_played'] = pd.to_datetime(data['last_played'])
data.set_index('last_played').resample('D').size().plot()
plt.title('User Engagement Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Plays')
plt.savefig("figures/user-engagement-overtime.png")
plt.show()
